# %%
import pandas as pd
import dtale
# Out:
# c:\Users\kriis\anaconda3\Lib\site-packages\kaleido\_sync_server.py:11: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]}) # pd.DataFrame() constructor to generate dataframe object.
#keys: column name
#values: are entries in df and should be array like objects.
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
              index=['Product A', 'Product B'])
# index parameter
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
#Series:
#1-D array like structure can be created from array like objects such as list, tuples, nd.array, etc.
#sets can be used but not recommended as they are unordered.
#for dataframe we can say series is a column.
pd.Series((1,2,3,4,5))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30,35,40], index=['2015 sales', '2020 sales', '2025 sales'], name='Product A')
#in series there's no column name it have a whole series name.
# Out:
# 2015 sales    30
# 2020 sales    35
# 2025 sales    40
# Name: Product A, dtype: int64

# %%
#Reading Data files:

# %%
#csv files 
wine_reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col=0) # read_csv() fucntion
wine_reviews.shape
#shape attribute to know how large dataframe is.
#we ca
# Out:
# (129971, 13)

# %%
wine_reviews.head() # head() method
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...
