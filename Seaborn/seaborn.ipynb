# %% [markdown]
# # Welcome to Data Visualization

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa_data = pd.read_csv(r"C:\Kaggle\Seaborn\fifa.csv", index_col='Date', parse_dates=True)
# Raw String r"" will tell python treat everything as string.
# parse_dates=True tells pandas to convert date/time columns into datetime objects

# %%
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
plt.figure(figsize=(16,6))
# set the width and height of figure(blank canvas)
sns.lineplot(data=fifa_data)
# creating linechart and it only work with numerical columns in dataframe.
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Line Charts

# %%
spotify_filepath = "C:\Kaggle\Seaborn\spotify.csv"

spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)
spotify_data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\kriis\AppData\Local\Temp\ipykernel_2648\1898022723.py:1: SyntaxWarning: invalid escape sequence '\K'
#   spotify_filepath = "C:\Kaggle\Seaborn\spotify.csv"
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
# LineChart
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(14,6))

# Adding title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

sns.lineplot(data=spotify_data)
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %%
# converting dataframe columns into list.
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
plt.figure(figsize=(14,6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line Chart only "Shape of You"
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

#Line Chart only of "Despacito"
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# label for horizontal axis not mandatory but recommended.
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # Bar Charts and Heatmaps

# %%
flight_data = pd.read_csv(r"C:\Kaggle\Seaborn\flight_delays.csv", index_col="Month")
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize=(14,6))
plt.title('Average Arrival Delay for Spirit Airlines')
plt.ylabel('Arrival Delay(in minutes)')
# Bar chart in which first argument is index and second is data.
sns.barplot(x=flight_data.index, y=flight_data['NK'])
# Out:
# <Axes: title={'center': 'Average Arrival Delay for Spirit Airlines'}, xlabel='Month', ylabel='Arrival Delay(in minutes)'>

# %%
# Heatmap
plt.figure(figsize=(14,7))

plt.title('Average Arrival Delay for Each Airline, by Month')

sns.heatmap(data=flight_data, annot=True)

plt.xlabel('Airline')
# annot=True will show the values in each cell.
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %% [markdown]
# # Scatter Plots

# %%
insurance_data = pd.read_csv(r"C:\Kaggle\Seaborn\insurance.csv")
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
plt.figure(figsize=(14,8))
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# adding Regression line
plt.figure(figsize=(14,8))
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## Color-coded Scatter plots

# %%
plt.figure(figsize=(14,8))
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# basically we can also able to use three varaibles for scatter plots.
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# creating two regression line
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance_data)

# %% [markdown]
# ## Categorical Scatter Plot

# %%
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'])
# Out:
# c:\Users\kriis\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# c:\Users\kriis\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Distributions

# %%
iris_data = pd.read_csv(r"C:\Kaggle\Seaborn\iris.csv", index_col=0)
iris_data
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %% [markdown]
# ## Histograms

# %%
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# ## Density plots

# %% [markdown]
# ### kernel density estimate(KDE) plot

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# shade=True to colour the curve
# Out:
# C:\Users\kriis\AppData\Local\Temp\ipykernel_2648\4079882345.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# ### two-dimensional(2D) KDE plot

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind='kde')

# %% [markdown]
# ## color-coded plots

# %%
# colored histogram
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')

plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %%
# colored kde plot
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)

plt.title("Distribution of Petal Lengths, by Species")
# Out:
# C:\Users\kriis\AppData\Local\Temp\ipykernel_2648\1601233039.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %% [markdown]
# # Choosing Plot Types and Custom Styles

# %%
spotify_data = pd.read_csv(r"C:\Kaggle\Seaborn\spotify.csv")
spotify_data
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
plt.figure(figsize=(16,7))
sns.set_style('dark') # changing theme of the figure
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,7))
sns.set_style('darkgrid')
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,7))
sns.set_style('whitegrid')
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,7))
sns.set_style('white')
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,7))
sns.set_style('ticks')
sns.lineplot(data=spotify_data)
# Out:
# <Axes: >

# %% [markdown]
# # Final Practice
